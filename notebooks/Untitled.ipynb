# %%
import pandas as pd

# %%
df=pd.read_csv("../data/compiled.labwas.csv",delimiter="\t")

# %%
df["#CHROM"].value_counts()
# Out:
# X     5085
# 17    1080
# 10     810
# 1      450
# 12     450
# 16     360
# 4      360
# 15     315
# 6      315
# 2      315
# 14     270
# 19     270
# 22     225
# 11     180
# 7      180
# 8      180
# 3      135
# 9       90
# 5       45
# Name: #CHROM, dtype: int64
