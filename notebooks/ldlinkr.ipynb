# %%
library(LDlinkR)

# %%
packageVersion("LDlinkR")
# Out:
# [1] ‘1.4.0’

# %%
lst <- read.csv("eur.rsid.txt")

# %%
LDproxy("rs1566561632", pop = "ALL", r2d = "r2",token="8cd14b73ba9c")
# Out:
# LDlink server is working...
#
#
#   error: rs1566561632 Variant is not in 1000G reference panel.
#   data_out[1, 1]
# 1   error: rs1566561632 Variant is not in 1000G reference panel.

# %%
LDproxy_batch(lst, pop = "CEU", r2d = "r2", append=TRUE, token="8cd14b73ba9c")
# Out:
# Submitting request for query variant rs34524635.
# Checking status of server...
# LDlink server is working...
# Submitting request for query variant rs28929474.
# Checking status of server...
# LDlink server is working...
# Submitting request for query variant rs56332871.
# Checking status of server...
# LDlink server is working...
# Submitting request for query variant rs1799941.
# Checking status of server...
# LDlink server is working...
# Submitting request for query variant rs202200760.
# Checking status of server...
# LDlink server is working...
# Submitting request for query variant rs4665972.
# Checking status of server...
# LDlink server is working...
# Submitting request for query variant rs881090.
# Checking status of server...
# LDlink server is working...
# Submitting request for query variant rs1956668.
# Checking status of server...
# LDlink server is working...
#
#
#   error: Variant is monoallelic in the chosen population(s).
# ...
